# %%
import math
import numpy as np
import h5py
import matplotlib.pyplot as plt
import tensorflow.compact.t1 as tf
from tensorflow.python.framework import ops
from tf_utils import load_dataset, random_mini_batches, convert_to_one_hot, predict

tf.diable_v2_behaviour()
# %matplotlib inline
np.random.seed(1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 5
#       3 import h5py
#       4 import matplotlib.pyplot as plt
# ----> 5 import tensorflow.compact.t1 as tf
#       6 from tensorflow.python.framework import ops
#       7 from tf_utils import load_dataset, random_mini_batches, convert_to_one_hot, predict
#
# ModuleNotFoundError: No module named 'tensorflow.compact'

# %%
y_hat = tf.constant(36, name="y_hat")
y = tf.constant(39, name='y')
loss = tf.Variable((y-y_hat) ** 2, name='loss')

init = tf.global_variables_initializer()
with tf.Session() as session:
    session.run(init)
    print(session.run(loss))

# %%
a = tf.constant(3)
b = tf.constant(30)
c = tf.multiply(a, b)

with tf.Session() as session:
    session.run(init)
    print(session.run(c))

# %%
sess = tf.Session()
xx = tf.placeholder(tf.int32, name='any_name')
res = sess.run(xx * 2, feed_dict={xx:30})
print(a.__dict__.items())
sess.close()
